# %%
## Topics Covered 
'''
 1. Claude AI vs Claude Code Vs Claude CoWork
 2. Pricing (free, Pro, Max)
 3. 

'''
# Out:
# '\n 1. Claude AI vs Claude Code Vs Claude CoWork\n 2. Pricing (free, Pro, Max)\n 3. \n\n'

# %%
#### INterface ########
## chats
'''
 - models 
 - VOice Mode
 - +(plus) : Use Style --> (Concise )
 - Connectors
'''

## Customize 
## Projects 
## Artifacts >> Mini Applications
## Code 
## Settings >> General 
##  >> account 
##  >> Usage 
## >> Capbilites 
##  >> Connectors

# %%
#### MODELS ########
# OPUS 
# SOnnet 
# Haiku 
# Extended Thinking ::: think about the problem first
# More

# %%
## Prompting ---> Overall Problem ---> 
## See as a assistant >>> give more contenxt in iterative manner

# %%
## ADd prompts with markdown --> 
## Learn MarkDown
