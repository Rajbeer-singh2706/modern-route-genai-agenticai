# %%
# https://www.youtube.com/watch?v=ImbmSEPo7qI&t=1917s

# %% [markdown]
# # Build an AI Customer Support Email Agent using Claude Code | Agentic AI Project

# %% [markdown]
# In this video, we will build a Customer Support Email Agentic AI System using Claude Code that can automatically read, understand, and respond to customer emails using AI agents.
#
# Instead of traditional automation, this system uses Agentic AI architecture, where multiple intelligent agents collaborate to analyze emails, retrieve relevant information, and generate accurate responses.
#
# You will learn how to design an AI-powered customer support automation system that can significantly reduce manual workload and improve response time.
#
# This project demonstrates how Claude Code, LLMs, and AI agents can be used to build real-world automation systems for businesses.
#
# If you are interested in Agentic AI, Generative AI, AI Agents, or building real-world LLM applications, this tutorial will help you understand how modern AI systems are designed.
#
# What you will learn in this video
# • What is an Agentic AI system
# • How AI agents can automate customer support emails
# • How Claude Code works for building AI applications
# • Designing an AI-powered email response system
# • Real-world architecture of an AI customer support agent
#
# Who should watch this video
# • AI Engineers
# • Generative AI Developers
# • Backend Developers
# • Automation Engineers
# • Anyone learning Agentic AI systems
#
# Technologies discussed
# Claude Code
# Agentic AI
# LLMs
# AI Agents
# Customer Support Automation
# AI Email Assistant
# Generative AI
#
# Subscribe for more Generative AI content
# If you want to learn Generative AI, RAG systems, AI Agents, and LLM engineering, make sure to subscribe to the channel.
# I regularly share tutorials on building real-world AI systems and production-grade GenAI projects.

# %%
# https://www.anthropic.com/news/introducing-claude
# https://claude.com/product/claude-code

# %% [markdown]
# ### products
# * Claude
# * Cluade Coode
# * Claude cowork

# %%
## Calude ---> chatbot 
# https://claude.ai/new

# %%
### Claude Code 
# 1. Documentation

# %%
## Calude code WIth ---> Pro Plan 
## Claude code with ---> APi Key

# %%
## https://platform.claude.com/dashboard
## API KEY ---> https://platform.claude.com/login?returnTo=%2F%3F
## Add $5

# %%
# cd E:\GEN_AI\modern-route-genai-agenticai\AICustomerSupport
# claude

# %%
# BOTH Are amazing ---> Explore Both ---> Claude COdE / Github Copilot /

# %%
# Tech Stack

# %%
## Folder Structure 
# customer_support_email_agent/

# %%
## DESIGN --> System (Low , High )

# %%
## Deployment

# %%
## Calude ---> can do 
'''
  --> can write a code 
  --> Can push to github 
  --> github action Pipeline 
  --> IAAS
  --> CONFIG 
   --> AWS 
'''
