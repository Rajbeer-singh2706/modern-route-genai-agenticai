# %%
## ✅ Steps

1. Install Git
2. Install Claude Code
3. Run `claude`
4. Choose login method
5. Setup billing (Pro / API)
6. Open project folder
7. Ask Claude to inspect project
8. Work module-by-module
9. Verify generated code
10. Run and test

# %%
## 🔹 Step 1 — Check Git

# Claude Code requires **Git for Windows / WSL**

# git --version


## 🔹 Step 2 — Install Claude Code
# Run in **PowerShell / CMD:**

irm https://claude.ai/install.ps1 | iex

# After installation, `claude.exe` gets installed in the local bin.

# %%
### Step 3:

# %%
### Step 4 — Choose Login Method
'''

Claude Code provides 3 login methods:

Claude account (Pro / Max subscription)
Anthropic Console (API billing)
Third-party cloud:
 * Amazon Bedrock
 * Google Vertex AI
 * Microsoft Foundry
'''
