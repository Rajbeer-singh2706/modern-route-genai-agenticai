# %%
## Claude MODE ---> PLAN/COMPACT

# %%
# E:\GEN_AI\modern-route-genai-agenticai\AICustomerSupport> 
# mkdir customer-support-email-agent 
# OPen a vscode in this location 
# code .

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## configure claude in this directory

## create a requirement.ext file with all the necessary requrement for agentic project

# %%
## calude copilot ---> install extenseion >>> Claude 

## Need to chek with chatgpt/claude , how to build step by step project using claude code

# %%
## create an Envrioment / Activate the enviroment

# %%
## ADD the OPENAI KEY ---> .ENV 
## key without 
#OPENAI_API_KEY=
#MODEL_NAME = "gpt-4o"

# %%
## RUN THE CODEBASE

# %%
################ DELOYMENT #####################
## Once done, need to work on deployment ---?
