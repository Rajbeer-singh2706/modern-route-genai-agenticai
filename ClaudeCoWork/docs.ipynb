# %%
## Claude EcoSystem --- 3 Layers 
'''
  1. Claude (Claude Chat AI)        --> Talk 
  2. Claude CODE (CLaude CODE AI)   --> Build 
  3. Claude CoWork(Claude CoWork AI)
'''

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## Download the Claude ---> Pro Plan u will get the Cowork

# %%
## task 1 ---> organize ur files ---> in your local

# %%
### task2 --> give access to broser 
### Antropic ---> add on chrome ---> to give access to 

# comet browser
