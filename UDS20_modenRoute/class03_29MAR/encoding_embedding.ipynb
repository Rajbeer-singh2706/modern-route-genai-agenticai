# %%
print("all OK")
# Out:
# Running cells with 'env (3.12.12) (Python 3.12.12)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'e:/GEN_AI/env/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
