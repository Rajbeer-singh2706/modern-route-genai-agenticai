# %%
####
#Introduction of Modern GenAI and LLMs (Modern Route-Full Stack GenerativeAI And Agentic AI Bootcam)

# %%
###1 coding assistant ####
1. setup tyhre copilot in your vscode
2. clade 
3. open ai coiex


### id ---- cursor, antigravoity

# %%
### MOde : Ask / Agent 
# Agent --> can change

# %%
INtroduction to genAI


AI --> ML (machine Kearning)
AI --> DL (Deep Learning): Neural network 
AI ---> RL(reinforemcent Learning)

# %%
ANN -->
CNN --> Con
RNN --> 
GAN
DRL --> Deep

# %%
### Tools important for GENAI #####
PyTorch
Huggingface
unSloth
4. LangChain
5. llamaIndex
6. LangGraph
7. DP ( vector Databaswe, Cloud )
8. OpenAISDK
9. GuardRails
10. MCP

# %%
# create venv with 3.12 or 3.11 
E:\GEN_AI>uv python list


uv venv env --python cpython-3.12.13-windows-x86_64-none 

uv venv env --python 3.11
env\Scripts\activate
uv pip install -r requirements.txt
